# %% [markdown]
# Based on
#
# - https://github.com/pytorch/examples/blob/87d9a1e930b5b813/reinforcement_learning/reinforce.py
# - https://medium.com/@ts1829/policy-gradient-reinforcement-learning-in-pytorch-df1383ea0baf [Notebook](https://nbviewer.jupyter.org/urls/gist.githubusercontent.com/ts1829/ebbe2cf946bf36951b724818c52e36b9/raw/4da449bffe9835e201f2fb34f381fbb53568d1ca/Policy%20Gradient%20with%20Cartpole%20and%20PyTorch%20%28Medium%20Version%29.ipynb)

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import count
import itertools
from collections import namedtuple, defaultdict
from tqdm import tqdm, trange
import os
import json
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch.distributions import Categorical
# %matplotlib inline

import random
from tuplestate import *
from gamestate import *
from benchmarking import *
from vectorize import *
random.seed(0)
# print(to_pretty_string(klonstate))

# %%
all_solutions = os.listdir('./bench/shootme/')

def solve_state(ret):
    lines = ret.splitlines()
    result = lines[15]
    if result.startswith('Minimal solution'):
        return "Solved-Min"
    elif result.startswith("Solved"):
        return "Solved"
    elif result.startswith('Impossible'):
        return "Impossible"
    elif result.startswith('Unknown'):
        return "Unknown"

def clf_seeds(seedlist):
    results = defaultdict(set)
    for seed in seedlist:
        with open(f"./bench/shootme/{seed}") as f:
            ret = f.read()
            result = solve_state(ret)
            results[result].add(seed)
    return results

def clf_summary(seedlist):
    results = clf_seeds(seedlist)
    states = ['Solved-Min', 'Solved', 'Impossible', 'Unknown']
    for clfstate in states:
        seeds = results[clfstate]
        print(f"{clfstate:12} {len(seeds):8,}")
        total = sum(len(s) for s in results.values())
    print(('-'*12) + '-' + ('-'*8))
    print(f"{'Total':12} {total:8,}") 
          
def get_state(ret):
    deck_json = convert_shootme_to_solvitaire_json(ret)
    return init_from_solvitaire(deck_json)

def map_seeds_to_states(seed_seq):
    for seed in seed_seq:
        with open(f"bench/shootme/{seed}") as f:
            ret = f.read()
            state = get_state(ret)
            yield seed, state

print("All seeds")
clf_summary(all_solutions)
# Out:
# All seeds
# Solved-Min      7,876
# Solved            320
# Impossible      1,282
# Unknown           522
# ---------------------
# Total          10,000

# %% [markdown]
# - In features: game state vector of size $233 \times 104$
#
# - Out features: legal moves vector of size $623$

# %%
IN = 233*104
OUT = 623

Args = namedtuple('Args', 'gamma lr seed render log_interval')
args = Args(
    gamma=0.1,
    lr=5e-2,
    seed=1,
    render=False,
    log_interval=20)


class Policy(nn.Module):
    def __init__(self):
        super(Policy, self).__init__()
        self.inlayer = nn.Linear(IN, 233*10)
        self.linear1 = nn.Linear(233*10, 1000)
        self.outlayer = nn.Linear(1000, OUT)
        self.dropout = nn.Dropout(p=0.6)
        self.saved_log_probs = []
        self.rewards = []

    def forward(self, x):
        x = self.inlayer(x)
        x = F.relu(x)
        x = self.dropout(x)
        x = self.linear1(x)
        x = F.relu(x)
        action_scores = self.outlayer(x)
        return F.softmax(action_scores, dim=1)

def select_action(klonstate):
    state_vec = state_to_vec(klonstate)
    movefilter = vector_legal_moves(klonstate)
    torch_state_vec = torch.from_numpy(state_vec).float().reshape(-1).unsqueeze(0)
    torch_filter = torch.from_numpy(movefilter.astype(np.float32)).unsqueeze(0)
    probs = policy(torch_state_vec) * torch_filter
    if (probs == 0).all():
        torch_filter.requires_grad_()
        # sample all legal moves with uniform probability
        m = Categorical(torch_filter)
    else:
        # :attr:`probs` will be normalized to sum to 1
        m = Categorical(probs)
    action = m.sample()
    log_prob = m.log_prob(action)
    policy.saved_log_probs.append(log_prob)
    return action.item()

def finish_episode():
    R = 0
    policy_loss = []
    returns = []
    for r in policy.rewards[::-1]:
        R = r + args.gamma * R
        returns.insert(0, R)
    returns = torch.tensor(returns)
    returns = (returns - returns.mean()) / (returns.std() + eps)
    for log_prob, R in zip(policy.saved_log_probs, returns):
        policy_loss.append(-log_prob * R)
    optimizer.zero_grad()
    policy_loss = torch.cat(policy_loss).sum()
    policy_loss.backward()
    optimizer.step()
    del policy.rewards[:]
    del policy.saved_log_probs[:]
    
def step(curr_state, move_code):
    new_state = play_move(curr_state, move_code)
    reward = 0  
    if state_is_win(new_state) or all_cards_faceup(new_state):
        reward = 1
    if not state_is_legal(new_state):
        print('\n got illegal state by playing move', move_code)
        print('prev state')
        print(to_pretty_string(curr_state))
        print('\nnew state')
        print(to_pretty_string(new_state))
        assert state_is_legal(new_state), 'got illegal state'
    return new_state, reward

def score_state(klonstate):
    fnds = [klonstate.foundation1, klonstate.foundation2, 
            klonstate.foundation3, klonstate.foundation4]
    return sum(map(len, fnds))

# %%
policy = Policy()
optimizer = optim.SGD(policy.parameters(), lr=1e-2)
eps = np.finfo(np.float32).eps.item()

random.seed(0)
# train_seeds = random.sample(all_solutions, k=100)
# print('Training game set')
# clf_summary(train_seeds)

training_games = map_seeds_to_states(all_solutions)

for i, env in enumerate(training_games):
    seed, klonstate = env
#     print(seed)
    ep_reward = 0
    done = False
    path = []
    visited = set()
    for t in range(1, 1000):
        action_idx = select_action(klonstate)
        move_code = all_moves[action_idx]
        klonstate, reward = step(klonstate, move_code)
        path.append(move_code)
        if klonstate in visited:
            reward = -1
        else:
            visited.add(klonstate)
        done = reward != 0
#         if reward > 0:
#             # if it didnt hit a cycle then reward = state score
#             reward = score_state(klonstate)
#         elif reward < 0: # hit cycle
#             # few steps hitting a cycle gets large negative reward
#             # many steps hitting a cycle gets a smaller negative reward
#             reward = 10/(t * reward)
        policy.rewards.append(reward)
        ep_reward += reward
        if done:
#             print(f'{seed:11} done after {t:4} steps {ep_reward:.2f}')
            break
    print(f"{i:5}  ep reward {ep_reward:.2f}   steps {t:3}   ")#, end=' ')
#     print('final score', score_state(klonstate))
#     print('path', path)
#     print('final state')
#     print(to_pretty_string(klonstate))
    
    finish_episode()
# Out:
#     0  ep reward -1.00   steps   6
#     1  ep reward -1.00   steps   9
#     2  ep reward -1.00   steps   6
#     3  ep reward -1.00   steps  10
#     4  ep reward -1.00   steps   4
#     5  ep reward -1.00   steps  10
#     6  ep reward -1.00   steps  11
#     7  ep reward -1.00   steps   5
#     8  ep reward -1.00   steps   8
#     9  ep reward -1.00   steps   6
#    10  ep reward -1.00   steps   4
#    11  ep reward -1.00   steps   4
#    12  ep reward -1.00   steps  21
#    13  ep reward -1.00   steps  11
#    14  ep reward -1.00   steps   6
#    15  ep reward -1.00   steps   9
#    16  ep reward -1.00   steps  11
#    17  ep reward -1.00   steps   7
#    18  ep reward -1.00   steps   7
#    19  ep reward -1.00   steps   9
#    20  ep reward -1.00   steps   4
#    21  ep reward -1.00   steps   6
#    22  ep reward -1.00   steps  28
#    23  ep reward -1.00   steps   9
#    24  ep reward -1.00   steps   5
#    25  ep reward -1.00   steps  11
#    26  ep reward -1.00   steps  24
#    27  ep reward -1.00   steps   3
#    28  ep reward -1.00   steps  32
#    29  ep reward -1.00   steps  10
#    30  ep reward -1.00   steps  13
#    31  ep reward -1.00   steps   5
#    32  ep reward -1.00   steps  14
#    33  ep reward -1.00   steps   5
#    34  ep reward -1.00   steps   6
#    35  ep reward -1.00   steps  16
#    36  ep reward -1.00   steps  10
#    37  ep reward -1.00   steps   8
#    38  ep reward -1.00   steps  16
#    39  ep reward -1.00   steps   6
#    40  ep reward -1.00   steps   6
#    41  ep reward -1.00   steps   5
#    42  ep reward -1.00   steps  13
#    43  ep reward -1.00   steps   6
#    44  ep reward -1.00   steps   5
#    45  ep reward -1.00   steps  10
#    46  ep reward -1.00   steps  17
#    47  ep reward -1.00   steps  11
#    48  ep reward -1.00   steps   4
#    49  ep reward -1.00   steps   9
#    50  ep reward -1.00   steps  15
#    51  ep reward -1.00   steps   5
#    52  ep reward -1.00   steps  15
#    53  ep reward -1.00   steps   4
#    54  ep reward -1.00   steps   5
#    55  ep reward -1.00   steps   4
#    56  ep reward -1.00   steps  12
#    57  ep reward -1.00   steps   6
#    58  ep reward -1.00   steps  35
#    59  ep reward -1.00   steps   4
#    60  ep reward -1.00   steps   3
#    61  ep reward -1.00   steps  40
#    62  ep reward -1.00   steps   6
#    63  ep reward -1.00   steps  20
#    64  ep reward -1.00   steps   6
#    65  ep reward -1.00   steps   8
#    66  ep reward -1.00   steps   4
#    67  ep reward -1.00   steps   7
#    68  ep reward -1.00   steps   3
#    69  ep reward -1.00   steps  10
#    70  ep reward -1.00   steps   4
#    71  ep reward -1.00   steps   5
#    72  ep reward -1.00   steps  15
#    73  ep reward -1.00   steps   6
#    74  ep reward -1.00   steps   7
#    75  ep reward -1.00   steps   4
#    76  ep reward -1.00   steps   3
#    77  ep reward -1.00   steps   5
#    78  ep reward -1.00   steps   6
#    79  ep reward -1.00   steps  11
#    80  ep reward -1.00   steps   7
#    81  ep reward -1.00   steps   5
#    82  ep reward -1.00   steps  11
#    83  ep reward -1.00   steps   3
#    84  ep reward -1.00   steps  12
#    85  ep reward -1.00   steps   7
#    86  ep reward -1.00   steps   5
#    87  ep reward -1.00   steps   9
#    88  ep reward -1.00   steps   4
#    89  ep reward -1.00   steps   5
#    90  ep reward -1.00   steps   5
#    91  ep reward -1.00   steps  27
#    92  ep reward -1.00   steps   7
#    93  ep reward -1.00   steps   3
#    94  ep reward -1.00   steps   8
#    95  ep reward -1.00   steps   6
#    96  ep reward -1.00   steps  10
#    97  ep reward -1.00   steps   5
#    98  ep reward -1.00   steps   7
#    99  ep reward -1.00   steps   9
#   100  ep reward -1.00   steps   6
#   101  ep reward -1.00   steps   5
#   102  ep reward -1.00   steps   3
#   103  ep reward -1.00   steps   6
#   104  ep reward -1.00   steps   4
#   105  ep reward -1.00   steps  11
#   106  ep reward -1.00   steps   8
#   107  ep reward -1.00   steps   5
#   108  ep reward -1.00   steps   5
#   109  ep reward -1.00   steps   6
#   110  ep reward -1.00   steps   8
#   111  ep reward -1.00   steps  12
#   112  ep reward -1.00   steps   6
#   113  ep reward -1.00   steps  10
#   114  ep reward -1.00   steps   4
#   115  ep reward -1.00   steps   4
#   116  ep reward -1.00   steps   9
#   117  ep reward -1.00   steps   6
#   118  ep reward -1.00   steps   3
#   119  ep reward -1.00   steps   6
#   120  ep reward -1.00   steps   4
#   121  ep reward -1.00   steps   4
#   122  ep reward -1.00   steps  15
#   123  ep reward -1.00   steps   4
#   124  ep reward -1.00   steps  17
#   125  ep reward -1.00   steps   9
#   126  ep reward -1.00   steps  14
#   127  ep reward -1.00   steps   4
#   128  ep reward -1.00   steps   9
#   129  ep reward -1.00   steps   4
#   130  ep reward -1.00   steps   4
#   131  ep reward -1.00   steps   4
#   132  ep reward -1.00   steps   4
#   133  ep reward -1.00   steps   4
#   134  ep reward -1.00   steps   7
#   135  ep reward -1.00   steps   8
#   136  ep reward -1.00   steps  14
#   137  ep reward -1.00   steps  10
#   138  ep reward -1.00   steps  10
#   139  ep reward -1.00   steps   4
#   140  ep reward -1.00   steps   7
#   141  ep reward -1.00   steps   4
#   142  ep reward -1.00   steps   6
#   143  ep reward -1.00   steps  17
#   144  ep reward -1.00   steps   6
#   145  ep reward -1.00   steps   5
#   146  ep reward -1.00   steps   7
#   147  ep reward -1.00   steps   7
#   148  ep reward -1.00   steps  20
#   149  ep reward -1.00   steps   6
#   150  ep reward -1.00   steps  18
#   151  ep reward -1.00   steps  15
#   152  ep reward -1.00   steps  15
#   153  ep reward -1.00   steps  14
#   154  ep reward -1.00   steps  27
#   155  ep reward -1.00   steps   3
#   156  ep reward -1.00   steps   8
#   157  ep reward -1.00   steps  15
#   158  ep reward -1.00   steps   6
#   159  ep reward -1.00   steps   3
#   160  ep reward -1.00   steps  10
#   161  ep reward -1.00   steps  12
#   162  ep reward -1.00   steps   5
#   163  ep reward -1.00   steps   3
#   164  ep reward -1.00   steps   5
#   165  ep reward -1.00   steps   5
#   166  ep reward -1.00   steps   7
#   167  ep reward -1.00   steps   9
#   168  ep reward -1.00   steps   4
#   169  ep reward -1.00   steps   6
#   170  ep reward -1.00   steps   7
#   171  ep reward -1.00   steps   9
#   172  ep reward -1.00   steps   9
#   173  ep reward -1.00   steps   7
#   174  ep reward -1.00   steps  18
#   175  ep reward -1.00   steps   5
#   176  ep reward -1.00   steps  11
#   177  ep reward -1.00   steps  22
#   178  ep reward -1.00   steps   6
#   179  ep reward -1.00   steps  14
#   180  ep reward -1.00   steps   6
#   181  ep reward -1.00   steps  22
#   182  ep reward -1.00   steps   8
#   183  ep reward -1.00   steps   8
#   184  ep reward -1.00   steps  22
#   185  ep reward -1.00   steps  11
#   186  ep reward -1.00   steps  12
#   187  ep reward -1.00   steps   8
#   188  ep reward -1.00   steps  12
#   189  ep reward -1.00   steps   6
#   190  ep reward -1.00   steps   4
#   191  ep reward -1.00   steps   4
#   192  ep reward -1.00   steps   8
#   193  ep reward -1.00   steps  11
#   194  ep reward -1.00   steps   8
#   195  ep reward -1.00   steps  11
#   196  ep reward -1.00   steps   8
#   197  ep reward -1.00   steps  16
#   198  ep reward -1.00   steps   7
#   199  ep reward -1.00   steps  17
#   200  ep reward -1.00   steps  23
#   201  ep reward -1.00   steps   6
#   202  ep reward -1.00   steps   7
#   203  ep reward -1.00   steps   5
#   204  ep reward -1.00   steps  10
#   205  ep reward -1.00   steps  19
#   206  ep reward -1.00   steps   7
#   207  ep reward -1.00   steps   3
#   208  ep reward -1.00   steps   6
#   209  ep reward -1.00   steps   6
#   210  ep reward -1.00   steps  27
#   211  ep reward -1.00   steps   4
#   212  ep reward -1.00   steps  10
#   213  ep reward -1.00   steps   3
#   214  ep reward -1.00   steps  16
#   215  ep reward -1.00   steps   9
#   216  ep reward -1.00   steps   8
#   217  ep reward -1.00   steps   5
#   218  ep reward -1.00   steps   6
#   219  ep reward -1.00   steps   5
#   220  ep reward -1.00   steps   4
#   221  ep reward -1.00   steps   9
#   222  ep reward -1.00   steps  18
#   223  ep reward -1.00   steps   8
#   224  ep reward -1.00   steps  15
#   225  ep reward -1.00   steps   5
#   226  ep reward -1.00   steps  11
#   227  ep reward -1.00   steps  10
#   228  ep reward -1.00   steps   9
#   229  ep reward -1.00   steps   5
#   230  ep reward -1.00   steps  11
#   231  ep reward -1.00   steps  25
#   232  ep reward -1.00   steps  16
#   233  ep reward -1.00   steps   4
#   234  ep reward -1.00   steps   6
#   235  ep reward -1.00   steps   3
#   236  ep reward -1.00   steps   8
#   237  ep reward -1.00   steps   7
#   238  ep reward -1.00   steps   3
#   239  ep reward -1.00   steps   5
#   240  ep reward -1.00   steps  17
#   241  ep reward -1.00   steps   6
#   242  ep reward -1.00   steps   6
#   243  ep reward -1.00   steps   7
#   244  ep reward -1.00   steps   7
#   245  ep reward -1.00   steps   5
#   246  ep reward -1.00   steps  11
#   247  ep reward -1.00   steps   4
#   248  ep reward -1.00   steps   5
#   249  ep reward -1.00   steps   3
#   250  ep reward -1.00   steps  10
#   251  ep reward -1.00   steps  10
#   252  ep reward -1.00   steps   7
#   253  ep reward -1.00   steps   3
#   254  ep reward -1.00   steps  13
#   255  ep reward -1.00   steps   8
#   256  ep reward -1.00   steps   4
#   257  ep reward -1.00   steps   6
#   258  ep reward -1.00   steps  18
#   259  ep reward -1.00   steps   4
#   260  ep reward -1.00   steps   3
#   261  ep reward -1.00   steps  16
#   262  ep reward -1.00   steps   4
#   263  ep reward -1.00   steps   9
#   264  ep reward -1.00   steps  13
#   265  ep reward -1.00   steps   5
#   266  ep reward -1.00   steps   7
#   267  ep reward -1.00   steps  19
#   268  ep reward -1.00   steps   6
#   269  ep reward -1.00   steps   9
#   270  ep reward -1.00   steps   8
#   271  ep reward -1.00   steps   4
#   272  ep reward -1.00   steps   5
#   273  ep reward -1.00   steps   4
#   274  ep reward -1.00   steps  13
#   275  ep reward -1.00   steps   3
#   276  ep reward -1.00   steps  18
#   277  ep reward -1.00   steps   5
#   278  ep reward -1.00   steps   7
#   279  ep reward -1.00   steps   9
#   280  ep reward -1.00   steps   6
#   281  ep reward -1.00   steps  15
#   282  ep reward -1.00   steps   5
#   283  ep reward -1.00   steps  10
#   284  ep reward -1.00   steps   3
#   285  ep reward -1.00   steps  14
#   286  ep reward -1.00   steps   4
#   287  ep reward -1.00   steps   4
#   288  ep reward -1.00   steps   5
#   289  ep reward -1.00   steps  12
#   290  ep reward -1.00   steps   9
#   291  ep reward -1.00   steps   6
#   292  ep reward -1.00   steps   7
#   293  ep reward -1.00   steps  16
#   294  ep reward -1.00   steps   6
#   295  ep reward -1.00   steps   6
#   296  ep reward -1.00   steps  15
#   297  ep reward -1.00   steps   7
#   298  ep reward -1.00   steps  12
#   299  ep reward -1.00   steps   4
#   300  ep reward -1.00   steps   7
#   301  ep reward -1.00   steps  16
#   302  ep reward -1.00   steps   6
#   303  ep reward -1.00   steps   6
#   304  ep reward -1.00   steps  26
#   305  ep reward -1.00   steps  13
#   306  ep reward -1.00   steps  10
#   307  ep reward -1.00   steps  13
#   308  ep reward -1.00   steps  10
#   309  ep reward -1.00   steps  20
#   310  ep reward -1.00   steps  23
#   311  ep reward -1.00   steps   7
#   312  ep reward -1.00   steps   7
#   313  ep reward -1.00   steps   3
#   314  ep reward -1.00   steps   6
#   315  ep reward -1.00   steps  11
#   316  ep reward -1.00   steps   6
#   317  ep reward -1.00   steps   6
#   318  ep reward -1.00   steps  14
#   319  ep reward -1.00   steps   4
#   320  ep reward -1.00   steps   4
#   321  ep reward -1.00   steps   7
#   322  ep reward -1.00   steps   8
#   323  ep reward -1.00   steps   4
#   324  ep reward -1.00   steps   9
#   325  ep reward -1.00   steps   7
#   326  ep reward -1.00   steps   4
#   327  ep reward -1.00   steps   7
#   328  ep reward -1.00   steps   5
#   329  ep reward -1.00   steps  23
#   330  ep reward -1.00   steps   8
#   331  ep reward -1.00   steps   8
#   332  ep reward -1.00   steps   7
#   333  ep reward -1.00   steps   4
#   334  ep reward -1.00   steps   3
#   335  ep reward -1.00   steps   3
#   336  ep reward -1.00   steps  15
#   337  ep reward -1.00   steps   8
#   338  ep reward -1.00   steps  18
#   339  ep reward -1.00   steps   4
#   340  ep reward -1.00   steps  13
#   341  ep reward -1.00   steps   9
#   342  ep reward -1.00   steps  11
#   343  ep reward -1.00   steps  14
#   344  ep reward -1.00   steps   7
#   345  ep reward -1.00   steps   6
#   346  ep reward -1.00   steps   3
#   347  ep reward -1.00   steps   7
#   348  ep reward -1.00   steps   9
#   349  ep reward -1.00   steps   5
#   350  ep reward -1.00   steps   5
#   351  ep reward -1.00   steps  11
#   352  ep reward -1.00   steps   5
#   353  ep reward -1.00   steps   5
#   354  ep reward -1.00   steps   7
#   355  ep reward -1.00   steps   6
#   356  ep reward -1.00   steps   3
#   357  ep reward -1.00   steps   5
#   358  ep reward -1.00   steps   8
#   359  ep reward -1.00   steps  16
#   360  ep reward -1.00   steps  13
#   361  ep reward -1.00   steps   5
#   362  ep reward -1.00   steps   6
#   363  ep reward -1.00   steps   4
#   364  ep reward -1.00   steps  13
#   365  ep reward -1.00   steps   9
#   366  ep reward -1.00   steps  13
#   367  ep reward -1.00   steps   9
#   368  ep reward -1.00   steps   6
#   369  ep reward -1.00   steps  12
#   370  ep reward -1.00   steps   6
#   371  ep reward -1.00   steps  18
#   372  ep reward -1.00   steps   5
#   373  ep reward -1.00   steps  23
#   374  ep reward -1.00   steps   5
#   375  ep reward -1.00   steps  10
#   376  ep reward -1.00   steps   6
#   377  ep reward -1.00   steps   3
#   378  ep reward -1.00   steps   5
#   379  ep reward -1.00   steps   6
#   380  ep reward -1.00   steps   4
#   381  ep reward -1.00   steps   7
#   382  ep reward -1.00   steps   4
#   383  ep reward -1.00   steps   5
#   384  ep reward -1.00   steps   6
#   385  ep reward -1.00   steps   7
#   386  ep reward -1.00   steps  23
#   387  ep reward -1.00   steps   6
#   388  ep reward -1.00   steps  11
#   389  ep reward -1.00   steps   7
#   390  ep reward -1.00   steps   5
#   391  ep reward -1.00   steps  10
#   392  ep reward -1.00   steps   6
#   393  ep reward -1.00   steps  12
#   394  ep reward -1.00   steps   7
#   395  ep reward -1.00   steps   4
#   396  ep reward -1.00   steps   7
#   397  ep reward -1.00   steps   8
#   398  ep reward -1.00   steps   3
#   399  ep reward -1.00   steps   7
#   400  ep reward -1.00   steps   9
#   401  ep reward -1.00   steps   8
#   402  ep reward -1.00   steps   8
#   403  ep reward -1.00   steps  12
#   404  ep reward -1.00   steps  12
#   405  ep reward -1.00   steps   5
#   406  ep reward -1.00   steps   7
#   407  ep reward -1.00   steps   4
#   408  ep reward -1.00   steps  10
#   409  ep reward -1.00   steps  16
#   410  ep reward -1.00   steps   6
#   411  ep reward -1.00   steps   4
#   412  ep reward -1.00   steps   9
#   413  ep reward -1.00   steps   7
#   414  ep reward -1.00   steps   5
#   415  ep reward -1.00   steps   4
#   416  ep reward -1.00   steps  12
#   417  ep reward -1.00   steps   9
#   418  ep reward -1.00   steps  20
#   419  ep reward -1.00   steps   5
#   420  ep reward -1.00   steps   7
#   421  ep reward -1.00   steps  14
#   422  ep reward -1.00   steps  10
#   423  ep reward -1.00   steps  14
#   424  ep reward -1.00   steps   5
#   425  ep reward -1.00   steps   9
#   426  ep reward -1.00   steps   9
#   427  ep reward -1.00   steps   4
#   428  ep reward -1.00   steps   9
#   429  ep reward -1.00   steps   7
#   430  ep reward -1.00   steps   6
#   431  ep reward -1.00   steps  12
#   432  ep reward -1.00   steps   9
#   433  ep reward -1.00   steps   4
#   434  ep reward -1.00   steps   6
#   435  ep reward -1.00   steps   6
#   436  ep reward -1.00   steps   7
#   437  ep reward -1.00   steps   6
#   438  ep reward -1.00   steps   7
#   439  ep reward -1.00   steps   9
#   440  ep reward -1.00   steps  24
#   441  ep reward -1.00   steps  25
#   442  ep reward -1.00   steps   6
#   443  ep reward -1.00   steps  24
#   444  ep reward -1.00   steps  13
#   445  ep reward -1.00   steps   6
#   446  ep reward -1.00   steps   5
#   447  ep reward -1.00   steps   6
#   448  ep reward -1.00   steps  14
#   449  ep reward -1.00   steps   4
#   450  ep reward -1.00   steps  21
#   451  ep reward -1.00   steps  18
#   452  ep reward -1.00   steps  17
#   453  ep reward -1.00   steps   5
#   454  ep reward -1.00   steps   8
#   455  ep reward -1.00   steps   5
#   456  ep reward -1.00   steps  12
#   457  ep reward -1.00   steps   5
#   458  ep reward -1.00   steps   7
#   459  ep reward -1.00   steps  10
#   460  ep reward -1.00   steps   4
#   461  ep reward -1.00   steps   5
#   462  ep reward -1.00   steps   3
#   463  ep reward -1.00   steps   6
#   464  ep reward -1.00   steps   8
#   465  ep reward -1.00   steps  15
#   466  ep reward -1.00   steps  20
#   467  ep reward -1.00   steps  17
#   468  ep reward -1.00   steps   9
#   469  ep reward -1.00   steps  22
#   470  ep reward -1.00   steps   4
#   471  ep reward -1.00   steps  20
#   472  ep reward -1.00   steps   5
#   473  ep reward -1.00   steps   8
#   474  ep reward -1.00   steps   5
#   475  ep reward -1.00   steps   4
#   476  ep reward -1.00   steps   6
#   477  ep reward -1.00   steps   7
#   478  ep reward -1.00   steps  15
#   479  ep reward -1.00   steps   3
#   480  ep reward -1.00   steps   6
#   481  ep reward -1.00   steps   3
#   482  ep reward -1.00   steps   8
#   483  ep reward -1.00   steps   7
#   484  ep reward -1.00   steps   5
#   485  ep reward -1.00   steps   5
#   486  ep reward -1.00   steps   7
#   487  ep reward -1.00   steps  12
#   488  ep reward -1.00   steps  13
#   489  ep reward -1.00   steps  10
#   490  ep reward -1.00   steps   8
#   491  ep reward -1.00   steps   5
#   492  ep reward -1.00   steps  13
#   493  ep reward -1.00   steps   4
#   494  ep reward -1.00   steps  20
#   495  ep reward -1.00   steps   7
#   496  ep reward -1.00   steps   5
#   497  ep reward -1.00   steps  18
#   498  ep reward -1.00   steps  10
#   499  ep reward -1.00   steps   3
#   500  ep reward -1.00   steps   3
#   501  ep reward -1.00   steps   7
#   502  ep reward -1.00   steps  10
#   503  ep reward -1.00   steps   6
#   504  ep reward -1.00   steps  12
#   505  ep reward -1.00   steps  16
#   506  ep reward -1.00   steps   6
#   507  ep reward -1.00   steps  12
#   508  ep reward -1.00   steps   5
#   509  ep reward -1.00   steps   9
#   510  ep reward -1.00   steps   8
#   511  ep reward -1.00   steps   6
#   512  ep reward -1.00   steps   6
#   513  ep reward -1.00   steps  13
#   514  ep reward -1.00   steps  11
#   515  ep reward -1.00   steps   5
#   516  ep reward -1.00   steps   8
#   517  ep reward -1.00   steps   3
#   518  ep reward -1.00   steps  18
#   519  ep reward -1.00   steps  22
#   520  ep reward -1.00   steps   6
#   521  ep reward -1.00   steps  11
#   522  ep reward -1.00   steps   7
#   523  ep reward -1.00   steps   7
#   524  ep reward -1.00   steps  13
#   525  ep reward -1.00   steps   6
#   526  ep reward -1.00   steps   5
#   527  ep reward -1.00   steps   5
#   528  ep reward -1.00   steps  10
#   529  ep reward -1.00   steps   5
#   530  ep reward -1.00   steps   4
#   531  ep reward -1.00   steps   9
#   532  ep reward -1.00   steps   5
#   533  ep reward -1.00   steps   6
#   534  ep reward -1.00   steps   3
#   535  ep reward -1.00   steps  19
#   536  ep reward -1.00   steps  12
#   537  ep reward -1.00   steps   9
#   538  ep reward -1.00   steps   8
#   539  ep reward -1.00   steps  19
#   540  ep reward -1.00   steps  12
#   541  ep reward -1.00   steps   8
#   542  ep reward -1.00   steps  18
#   543  ep reward -1.00   steps  18
#   544  ep reward -1.00   steps   4
#   545  ep reward -1.00   steps   6
#   546  ep reward -1.00   steps   6
#   547  ep reward -1.00   steps   6
#   548  ep reward -1.00   steps  20
#   549  ep reward -1.00   steps  37
#   550  ep reward -1.00   steps   9
#   551  ep reward -1.00   steps  15
#   552  ep reward -1.00   steps   8
#   553  ep reward -1.00   steps   4
#   554  ep reward -1.00   steps  11
#   555  ep reward -1.00   steps   6
#   556  ep reward -1.00   steps  14
#   557  ep reward -1.00   steps  16
#   558  ep reward -1.00   steps  28
#   559  ep reward -1.00   steps  17
#   560  ep reward -1.00   steps  11
#   561  ep reward -1.00   steps   5
#   562  ep reward -1.00   steps   5
#   563  ep reward -1.00   steps   5
#   564  ep reward -1.00   steps  12
#   565  ep reward -1.00   steps   6
#   566  ep reward -1.00   steps   6
#   567  ep reward -1.00   steps   8
#   568  ep reward -1.00   steps  14
#   569  ep reward -1.00   steps   6
#   570  ep reward -1.00   steps  18
#   571  ep reward -1.00   steps   6
#   572  ep reward -1.00   steps  14
#   573  ep reward -1.00   steps   6
#   574  ep reward -1.00   steps   5
#   575  ep reward -1.00   steps   8
#   576  ep reward -1.00   steps  16
#   577  ep reward -1.00   steps  20
#   578  ep reward -1.00   steps   7
#   579  ep reward -1.00   steps  17
#   580  ep reward -1.00   steps   5
#   581  ep reward -1.00   steps   4
#   582  ep reward -1.00   steps   6
#   583  ep reward -1.00   steps  14
#   584  ep reward -1.00   steps   8
#   585  ep reward -1.00   steps  18
#   586  ep reward -1.00   steps   5
#   587  ep reward -1.00   steps   7
#   588  ep reward -1.00   steps  18
#   589  ep reward -1.00   steps  13
#   590  ep reward -1.00   steps   6
#   591  ep reward -1.00   steps   4
#   592  ep reward -1.00   steps  10
#   593  ep reward -1.00   steps  15
#   594  ep reward -1.00   steps   5
#   595  ep reward -1.00   steps  12
#   596  ep reward -1.00   steps   6
#   597  ep reward -1.00   steps   9
#   598  ep reward -1.00   steps  16
#   599  ep reward -1.00   steps   3
#   600  ep reward -1.00   steps  13
#   601  ep reward -1.00   steps  18
#   602  ep reward -1.00   steps   4
#   603  ep reward -1.00   steps   6
#   604  ep reward -1.00   steps   4
#   605  ep reward -1.00   steps  13
#   606  ep reward -1.00   steps  19
#   607  ep reward -1.00   steps  16
#   608  ep reward -1.00   steps   4
#   609  ep reward -1.00   steps  15
#   610  ep reward -1.00   steps  22
#   611  ep reward -1.00   steps  16
#   612  ep reward -1.00   steps  24
#   613  ep reward -1.00   steps  12
#   614  ep reward -1.00   steps  14
#   615  ep reward -1.00   steps  14
#   616  ep reward -1.00   steps   3
#   617  ep reward -1.00   steps  11
#   618  ep reward -1.00   steps  11
#   619  ep reward -1.00   steps  20
#   620  ep reward -1.00   steps   6
#   621  ep reward -1.00   steps   7
#   622  ep reward -1.00   steps  29
#   623  ep reward -1.00   steps   6
#   624  ep reward -1.00   steps   5
#   625  ep reward -1.00   steps   3
#   626  ep reward -1.00   steps   7
#   627  ep reward -1.00   steps   8
#   628  ep reward -1.00   steps   6
#   629  ep reward -1.00   steps  13
#   630  ep reward -1.00   steps  13
#   631  ep reward -1.00   steps  25
#   632  ep reward -1.00   steps  23
#   633  ep reward -1.00   steps   6
#   634  ep reward -1.00   steps  16
#   635  ep reward -1.00   steps  11
#   636  ep reward -1.00   steps  12
#   637  ep reward -1.00   steps  10
#   638  ep reward -1.00   steps   6
#   639  ep reward -1.00   steps   7
#   640  ep reward -1.00   steps  17
#   641  ep reward -1.00   steps  16
#   642  ep reward -1.00   steps  19
#   643  ep reward -1.00   steps   9
#   644  ep reward -1.00   steps  18
#   645  ep reward -1.00   steps   5
#   646  ep reward -1.00   steps  15
#   647  ep reward -1.00   steps  30
#   648  ep reward -1.00   steps  24
#   649  ep reward -1.00   steps   4
#   650  ep reward -1.00   steps   7
#   651  ep reward -1.00   steps  16
#   652  ep reward -1.00   steps  18
#   653  ep reward -1.00   steps  10
#   654  ep reward -1.00   steps  14
#   655  ep reward -1.00   steps  13
#   656  ep reward -1.00   steps   3
#   657  ep reward -1.00   steps   8
#   658  ep reward -1.00   steps  20
#   659  ep reward -1.00   steps   7
#   660  ep reward -1.00   steps  14
#   661  ep reward -1.00   steps  23
#   662  ep reward -1.00   steps   9
#   663  ep reward -1.00   steps  10
#   664  ep reward -1.00   steps  11
#   665  ep reward -1.00   steps  30
#   666  ep reward -1.00   steps  28
#   667  ep reward -1.00   steps   7
#   668  ep reward -1.00   steps   9
#   669  ep reward -1.00   steps   4
#   670  ep reward -1.00   steps  39
#   671  ep reward -1.00   steps  25
#   672  ep reward -1.00   steps  16
#   673  ep reward -1.00   steps  14
#   674  ep reward -1.00   steps  38
#   675  ep reward -1.00   steps   5
#   676  ep reward -1.00   steps   8
#   677  ep reward -1.00   steps   5
#   678  ep reward -1.00   steps   7
#   679  ep reward -1.00   steps   6
#   680  ep reward -1.00   steps  18
#   681  ep reward -1.00   steps   6
#   682  ep reward -1.00   steps  14
#   683  ep reward -1.00   steps  19
#   684  ep reward -1.00   steps  16
#   685  ep reward -1.00   steps  17
#   686  ep reward -1.00   steps   5
#   687  ep reward -1.00   steps  11
#   688  ep reward -1.00   steps  19
#   689  ep reward -1.00   steps  14
#   690  ep reward -1.00   steps   9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-08f18a46571c> in <module>()
#      45 #     print(to_pretty_string(klonstate))
#      46
# ---> 47     finish_episode()
#
# <ipython-input-3-43babe77ae80> in finish_episode()
#      61     optimizer.zero_grad()
#      62     policy_loss = torch.cat(policy_loss).sum()
# ---> 63     policy_loss.backward()
#      64     optimizer.step()
#      65     del policy.rewards[:]
#
# /ada/projects/klonsolve/klonsolve/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# /ada/projects/klonsolve/klonsolve/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:
