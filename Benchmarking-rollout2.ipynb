# %%
import os
import time
import random
import shutil
import subprocess
import numpy as np
import pandas as pd
import multiprocessing
from datetime import datetime
from itertools import islice
from collections import defaultdict, namedtuple
from tuplestate import init_from_solvitaire, to_dict, pprint_st
from benchmarking import *
from solver import solve

# %%
def get_state(ret):
    deck_json = convert_shootme_to_solvitaire_json(ret)
    return init_from_solvitaire(deck_json)


def prepare_ui_state(ret):
    parsed = parse_winnable(ret)
    game_state = to_dict(get_state(ret))
    
    def card(c):
        ''' UI uses 10 instead of T '''
        return c.replace('t', '10').replace('T', '10')
    
    return {
        'stock': [card(c).lower() for c in game_state['stock']],
        'tableau': [
            [card(c) for c in tab] 
            for tab in game_state['tableau']
        ],
        'waste': game_state['waste'],
        'foundation': game_state['foundation'],
        'moveSeq': parsed['moves'].strip().split(' ')
    }

# %% [markdown]
# ## Read benchmark output

# %%
results = defaultdict(set)

all_solutions = os.listdir('./bench/shootme/')
seeds = list(map(lambda fname: int(fname[:-4]), all_solutions))

def solve_state(ret):
    lines = ret.splitlines()
    result = lines[15]
    if result.startswith('Minimal solution'):
        return "Solved-Min"
    elif result.startswith("Solved"):
        return "Solved"
    elif result.startswith('Impossible'):
        return "Impossible"
    elif result.startswith('Unknown'):
        return "Unknown"

for seed in sorted(seeds):
    with open(f"bench/shootme/{seed}.txt") as f:
        ret = f.read()
        result = solve_state(ret)
        results[result].add(seed)
    
seed_class = {}
for cls in results.keys():
    seeds_cls = results[cls]
    for seed in seeds_cls:
        seed_class[seed] = cls
        
for res, seeds in results.items():
    print(f"{res:12} {len(seeds):8,}")
total = sum(len(s) for s in results.values())
print(('-'*12) + '-' + ('-'*8))
print(f"{'Total':12} {total:8,}")
# Out:
# Solved-Min      7,876
# Impossible      1,282
# Unknown           522
# Solved            320
# ---------------------
# Total          10,000

# %% [markdown]
# ## Generate suites

# %%
# seeds = np.fromiter(seed_class.keys(), dtype=np.int16)
# rand = np.random.RandomState(0)

# def get_suites(size, max_suites):
#     rand.shuffle(seeds)
#     start = 0
#     suites = 0
#     for s in range(max_suites):
#         end = start + size
#         if end > len(seeds):
#             return
#         yield list(map(int, seeds[start:end]))
#         start = end
#         suites += 1

# size = 10
# for i, suite in enumerate(get_suites(size=size, max_suites=1000)):
#     with open(f'./bench/suites/{size}/suite_{i:0>4}.txt', 'w') as f:
#         out = ' '.join(map(str,suite))
#         f.write(out)

# %% [markdown]
# ## Run suites

# %%
def map_seeds_to_states(seed_seq):
    for seed in seed_seq:
        with open(f"bench/shootme/{seed}.txt") as f:
            ret = f.read()
            state = get_state(ret)
            yield seed, state

def get_seeds(fname):
    with open(fname) as f:
        return map(int, f.read().strip().split(' '))
    
    
def get_suite_states(fname):
    return list(map_seeds_to_states(get_seeds(fname)))


def get_suite_files(size):
    pref = f'./bench/suites/{size}/'
    ls = sorted(os.listdir(pref))
    if len(ls) == 0:
        raise Exception(f"no suite files in {pref}")
    return [os.path.join(pref, f) for f in ls]

# %%
Result = namedtuple('Result', 
    ['seed', 'time', 
     'solved', 'visited', 'msg',
     'seq', 'seqlen', 
     'datetime', 'shootme']
)

def run_solver(seedstate):
    seed, state = seedstate
#     print(f"starting seed {seed}")
    start = time.time()
    sol = solve(state, max_states=200_000, k=2)
    seq = None
    seqlen = -1
    if sol.solved:
        seq = " ".join(sol.moveseq)
        seqlen = len(seq)
    end = time.time()
    elapsed = end-start
    shootme = seed_class[seed]
    now = datetime.now().isoformat()
#     print(f"done solving {seed} after {elapsed:.1f}")
    return Result(
        seed=seed, time=elapsed,
        solved=sol.solved,
        visited=sol.visited,
        msg=sol.msg,
        seq=seq, seqlen=seqlen, 
        datetime=now, shootme=shootme
    )

# %%
proc = subprocess.Popen("git log --pretty=oneline | head -c 10", shell=True, stdout=subprocess.PIPE)
out, err = proc.communicate()
git = out.decode('ascii')
foldername = f"suite-10-rollout-k2-{git}"
folderpath = os.path.join("./bench/", foldername)

# %%
try:
    shutil.rmtree(folderpath)
except FileNotFoundError:
    pass
print(folderpath)

def timestr():
    now = datetime.now()
    return now.strftime("%Y%m%d-%H%M%S")

def save_results(results, suite_file):
    df = pd.DataFrame(results)
    fname = os.path.join(folderpath, f"{suite_file}-{timestr()}.csv")
    df.to_csv(fname)
# Out:
# ./bench/suite-10-rollout-k2-bf6bdd6e93

# %%
if not os.path.exists(folderpath):
    os.makedirs(folderpath)

with multiprocessing.Pool() as pool:
    for suite_file in get_suite_files(size=10):
#         print(f"starting {suite_file}")
        states = get_suite_states(suite_file)
        ret = pool.map(run_solver, states)
        _, fname = os.path.split(suite_file)
        fname, _ = os.path.splitext(fname)
        save_results(ret, fname)
        print(f'done {suite_file}')
# Out:
# done ./bench/suites/10/suite_0000.txt
# done ./bench/suites/10/suite_0001.txt
# done ./bench/suites/10/suite_0002.txt
# done ./bench/suites/10/suite_0003.txt
# done ./bench/suites/10/suite_0004.txt
# done ./bench/suites/10/suite_0005.txt
# done ./bench/suites/10/suite_0006.txt
# done ./bench/suites/10/suite_0007.txt
# done ./bench/suites/10/suite_0008.txt
# done ./bench/suites/10/suite_0009.txt
# done ./bench/suites/10/suite_0010.txt
# done ./bench/suites/10/suite_0011.txt
# done ./bench/suites/10/suite_0012.txt
# done ./bench/suites/10/suite_0013.txt
# done ./bench/suites/10/suite_0014.txt
# done ./bench/suites/10/suite_0015.txt
# done ./bench/suites/10/suite_0016.txt
# done ./bench/suites/10/suite_0017.txt
# done ./bench/suites/10/suite_0018.txt
# done ./bench/suites/10/suite_0019.txt
# done ./bench/suites/10/suite_0020.txt
# done ./bench/suites/10/suite_0021.txt
# done ./bench/suites/10/suite_0022.txt
# done ./bench/suites/10/suite_0023.txt
# done ./bench/suites/10/suite_0024.txt
# done ./bench/suites/10/suite_0025.txt
# done ./bench/suites/10/suite_0026.txt
# done ./bench/suites/10/suite_0027.txt
# done ./bench/suites/10/suite_0028.txt
# done ./bench/suites/10/suite_0029.txt
# done ./bench/suites/10/suite_0030.txt
# done ./bench/suites/10/suite_0031.txt
# done ./bench/suites/10/suite_0032.txt
# done ./bench/suites/10/suite_0033.txt
# done ./bench/suites/10/suite_0034.txt
# done ./bench/suites/10/suite_0035.txt
# done ./bench/suites/10/suite_0552.txt
# done ./bench/suites/10/suite_0553.txt
# done ./bench/suites/10/suite_0554.txt
# done ./bench/suites/10/suite_0555.txt
# done ./bench/suites/10/suite_0556.txt
# done ./bench/suites/10/suite_0557.txt
# done ./bench/suites/10/suite_0558.txt
# done ./bench/suites/10/suite_0559.txt
# done ./bench/suites/10/suite_0560.txt
# done ./bench/suites/10/suite_0561.txt
# done ./bench/suites/10/suite_0562.txt
# done ./bench/suites/10/suite_0563.txt
# done ./bench/suites/10/suite_0564.txt
# done ./bench/suites/10/suite_0565.txt
# done ./bench/suites/10/suite_0566.txt
# done ./bench/suites/10/suite_0567.txt
# done ./bench/suites/10/suite_0568.txt
# done ./bench/suites/10/suite_0569.txt
# done ./bench/suites/10/suite_0570.txt
# done ./bench/suites/10/suite_0571.txt
# done ./bench/suites/10/suite_0572.txt
# done ./bench/suites/10/suite_0573.txt
# done ./bench/suites/10/suite_0574.txt
# done ./bench/suites/10/suite_0575.txt
# done ./bench/suites/10/suite_0576.txt
# done ./bench/suites/10/suite_0577.txt
# done ./bench/suites/10/suite_0578.txt
# done ./bench/suites/10/suite_0579.txt
# done ./bench/suites/10/suite_0580.txt
# done ./bench/suites/10/suite_0581.txt
# done ./bench/suites/10/suite_0582.txt
# done ./bench/suites/10/suite_0583.txt
# done ./bench/suites/10/suite_0584.txt
# done ./bench/suites/10/suite_0585.txt
# done ./bench/suites/10/suite_0586.txt
# done ./bench/suites/10/suite_0587.txt
# done ./bench/suites/10/suite_0588.txt
# done ./bench/suites/10/suite_0589.txt
# done ./bench/suites/10/suite_0590.txt
# done ./bench/suites/10/suite_0591.txt
# done ./bench/suites/10/suite_0592.txt
# done ./bench/suites/10/suite_0593.txt
# done ./bench/suites/10/suite_0594.txt
# done ./bench/suites/10/suite_0595.txt
# done ./bench/suites/10/suite_0596.txt
# done ./bench/suites/10/suite_0597.txt
# done ./bench/suites/10/suite_0598.txt
# done ./bench/suites/10/suite_0599.txt
# done ./bench/suites/10/suite_0600.txt
# done ./bench/suites/10/suite_0601.txt
# done ./bench/suites/10/suite_0602.txt
# done ./bench/suites/10/suite_0603.txt
# done ./bench/suites/10/suite_0604.txt
# done ./bench/suites/10/suite_0605.txt
# done ./bench/suites/10/suite_0606.txt
# done ./bench/suites/10/suite_0607.txt
# done ./bench/suites/10/suite_0608.txt
# done ./bench/suites/10/suite_0609.txt
# done ./bench/suites/10/suite_0610.txt
# done ./bench/suites/10/suite_0611.txt
# done ./bench/suites/10/suite_0612.txt
# done ./bench/suites/10/suite_0613.txt
# done ./bench/suites/10/suite_0614.txt
# done ./bench/suites/10/suite_0615.txt
# done ./bench/suites/10/suite_0616.txt
# done ./bench/suites/10/suite_0617.txt
# done ./bench/suites/10/suite_0618.txt
# done ./bench/suites/10/suite_0619.txt
# done ./bench/suites/10/suite_0620.txt
# done ./bench/suites/10/suite_0621.txt
# done ./bench/suites/10/suite_0622.txt
# done ./bench/suites/10/suite_0623.txt
# done ./bench/suites/10/suite_0624.txt
# done ./bench/suites/10/suite_0625.txt
# done ./bench/suites/10/suite_0626.txt
# done ./bench/suites/10/suite_0627.txt
# done ./bench/suites/10/suite_0628.txt
# done ./bench/suites/10/suite_0629.txt
# done ./bench/suites/10/suite_0630.txt
# done ./bench/suites/10/suite_0631.txt
# done ./bench/suites/10/suite_0632.txt
# done ./bench/suites/10/suite_0633.txt
# done ./bench/suites/10/suite_0634.txt
# done ./bench/suites/10/suite_0635.txt
# done ./bench/suites/10/suite_0636.txt
# done ./bench/suites/10/suite_0637.txt
# done ./bench/suites/10/suite_0638.txt
# done ./bench/suites/10/suite_0639.txt
# done ./bench/suites/10/suite_0640.txt
# done ./bench/suites/10/suite_0641.txt
# done ./bench/suites/10/suite_0642.txt
# done ./bench/suites/10/suite_0643.txt
# done ./bench/suites/10/suite_0644.txt
# done ./bench/suites/10/suite_0645.txt
# done ./bench/suites/10/suite_0646.txt
# done ./bench/suites/10/suite_0647.txt
# done ./bench/suites/10/suite_0648.txt
# done ./bench/suites/10/suite_0649.txt
# done ./bench/suites/10/suite_0650.txt
# done ./bench/suites/10/suite_0651.txt
# done ./bench/suites/10/suite_0652.txt
# done ./bench/suites/10/suite_0653.txt
# done ./bench/suites/10/suite_0654.txt
# done ./bench/suites/10/suite_0655.txt
# done ./bench/suites/10/suite_0656.txt
# done ./bench/suites/10/suite_0657.txt
# done ./bench/suites/10/suite_0658.txt
# done ./bench/suites/10/suite_0659.txt
# done ./bench/suites/10/suite_0660.txt
# done ./bench/suites/10/suite_0661.txt
# done ./bench/suites/10/suite_0662.txt
# done ./bench/suites/10/suite_0663.txt
# done ./bench/suites/10/suite_0664.txt
# done ./bench/suites/10/suite_0665.txt
# done ./bench/suites/10/suite_0666.txt
# done ./bench/suites/10/suite_0667.txt
# done ./bench/suites/10/suite_0668.txt
# done ./bench/suites/10/suite_0669.txt
# done ./bench/suites/10/suite_0670.txt
# done ./bench/suites/10/suite_0671.txt
# done ./bench/suites/10/suite_0672.txt
# done ./bench/suites/10/suite_0673.txt
# done ./bench/suites/10/suite_0674.txt
# done ./bench/suites/10/suite_0675.txt
# done ./bench/suites/10/suite_0676.txt
# done ./bench/suites/10/suite_0677.txt
# done ./bench/suites/10/suite_0678.txt
# done ./bench/suites/10/suite_0679.txt
# done ./bench/suites/10/suite_0680.txt
# done ./bench/suites/10/suite_0681.txt
# done ./bench/suites/10/suite_0682.txt
# done ./bench/suites/10/suite_0683.txt
# done ./bench/suites/10/suite_0684.txt
# done ./bench/suites/10/suite_0685.txt
# done ./bench/suites/10/suite_0686.txt
# done ./bench/suites/10/suite_0687.txt
# done ./bench/suites/10/suite_0688.txt
# done ./bench/suites/10/suite_0689.txt
# done ./bench/suites/10/suite_0690.txt
# done ./bench/suites/10/suite_0691.txt
# done ./bench/suites/10/suite_0692.txt
# done ./bench/suites/10/suite_0693.txt
# done ./bench/suites/10/suite_0694.txt
# done ./bench/suites/10/suite_0695.txt
# done ./bench/suites/10/suite_0696.txt

# %%
# suite_file = './bench/suites/10/suite_0027.txt'
# states = get_suite_states(suite_file)
# ret = list(map(run_solver, states))
# ret
