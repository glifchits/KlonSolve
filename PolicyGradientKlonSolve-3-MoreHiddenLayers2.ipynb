# %% [markdown]
# Based on
#
# - https://github.com/pytorch/examples/blob/87d9a1e930b5b813/reinforcement_learning/reinforce.py
# - https://medium.com/@ts1829/policy-gradient-reinforcement-learning-in-pytorch-df1383ea0baf [Notebook](https://nbviewer.jupyter.org/urls/gist.githubusercontent.com/ts1829/ebbe2cf946bf36951b724818c52e36b9/raw/4da449bffe9835e201f2fb34f381fbb53568d1ca/Policy%20Gradient%20with%20Cartpole%20and%20PyTorch%20%28Medium%20Version%29.ipynb)

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import count
import itertools
from collections import namedtuple, defaultdict
from tqdm import tqdm, trange
import os
import json
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch.distributions import Categorical
# %matplotlib inline

import random
from tuplestate import *
from gamestate import *
from benchmarking import *
from vectorize import *
random.seed(0)
# print(to_pretty_string(klonstate))

# %%
all_solutions = os.listdir('./bench/shootme/')

def solve_state(ret):
    lines = ret.splitlines()
    result = lines[15]
    if result.startswith('Minimal solution'):
        return "Solved-Min"
    elif result.startswith("Solved"):
        return "Solved"
    elif result.startswith('Impossible'):
        return "Impossible"
    elif result.startswith('Unknown'):
        return "Unknown"

def clf_seeds(seedlist):
    results = defaultdict(set)
    for seed in seedlist:
        with open(f"./bench/shootme/{seed}") as f:
            ret = f.read()
            result = solve_state(ret)
            results[result].add(seed)
    return results

def clf_summary(seedlist):
    results = clf_seeds(seedlist)
    states = ['Solved-Min', 'Solved', 'Impossible', 'Unknown']
    for clfstate in states:
        seeds = results[clfstate]
        print(f"{clfstate:12} {len(seeds):8,}")
        total = sum(len(s) for s in results.values())
    print(('-'*12) + '-' + ('-'*8))
    print(f"{'Total':12} {total:8,}") 
          
def get_state(ret):
    deck_json = convert_shootme_to_solvitaire_json(ret)
    return init_from_solvitaire(deck_json)

def map_seeds_to_states(seed_seq):
    for seed in seed_seq:
        with open(f"bench/shootme/{seed}") as f:
            ret = f.read()
            state = get_state(ret)
            yield seed, state

print("All seeds")
clf_summary(all_solutions)
# Out:
# All seeds
# Solved-Min      7,876
# Solved            320
# Impossible      1,282
# Unknown           522
# ---------------------
# Total          10,000

# %% [markdown]
# - In features: game state vector of size $233 \times 104$
#
# - Out features: legal moves vector of size $623$

# %%
IN = 233*104
OUT = 623

Args = namedtuple('Args', 'gamma lr seed render log_interval')
args = Args(
    gamma=0.5,
    lr=5e-2,
    seed=1,
    render=False,
    log_interval=20)


class Policy(nn.Module):
    def __init__(self):
        super(Policy, self).__init__()
        self.inlayer = nn.Linear(IN, 233*50)
        self.linear1 = nn.Linear(233*50, 233*10)
        self.linear2 = nn.Linear(233*10, 1000)
        self.outlayer = nn.Linear(1000, OUT)
        self.dropout = nn.Dropout(p=0.6)
        self.saved_log_probs = []
        self.rewards = []

    def forward(self, x):
        x = self.inlayer(x)
        x = F.relu(x)
        x = self.dropout(x)
        x = self.linear1(x)
        x = F.relu(x)
        x = self.dropout(x)
        x = self.linear2(x)
        x = F.relu(x)
        action_scores = self.outlayer(x)
        return F.softmax(action_scores, dim=1)

def select_action(klonstate):
    state_vec = state_to_vec(klonstate)
    movefilter = vector_legal_moves(klonstate)
    torch_state_vec = torch.from_numpy(state_vec).float().reshape(-1).unsqueeze(0)
    torch_filter = torch.from_numpy(movefilter.astype(np.float32)).unsqueeze(0)
    probs = policy(torch_state_vec) * torch_filter
    if (probs == 0).all():
        torch_filter.requires_grad_()
        # sample all legal moves with uniform probability
        m = Categorical(torch_filter)
    else:
        # :attr:`probs` will be normalized to sum to 1
        m = Categorical(probs)
    action = m.sample()
    log_prob = m.log_prob(action)
    policy.saved_log_probs.append(log_prob)
    return action.item()

def finish_episode():
    R = 0
    policy_loss = []
    returns = []
    for r in policy.rewards[::-1]:
        R = r + args.gamma * R
        returns.insert(0, R)
    returns = torch.tensor(returns)
    returns = (returns - returns.mean()) / (returns.std() + eps)
    for log_prob, R in zip(policy.saved_log_probs, returns):
        policy_loss.append(-log_prob * R)
    optimizer.zero_grad()
    policy_loss = torch.cat(policy_loss).sum()
    policy_loss.backward()
    optimizer.step()
    del policy.rewards[:]
    del policy.saved_log_probs[:]
    
def step(curr_state, move_code):
    new_state = play_move(curr_state, move_code)
    reward = 0  
    if state_is_win(new_state) or all_cards_faceup(new_state):
        reward = 1
    if not state_is_legal(new_state):
        print('\n got illegal state by playing move', move_code)
        print('prev state')
        print(to_pretty_string(curr_state))
        print('\nnew state')
        print(to_pretty_string(new_state))
        assert state_is_legal(new_state), 'got illegal state'
    return new_state, reward

def score_state(klonstate):
    fnds = [klonstate.foundation1, klonstate.foundation2, 
            klonstate.foundation3, klonstate.foundation4]
    return sum(map(len, fnds))

# %%
policy = Policy()
optimizer = optim.SGD(policy.parameters(), lr=1e-2)
eps = np.finfo(np.float32).eps.item()

random.seed(0)
# train_seeds = random.sample(all_solutions, k=100)
# print('Training game set')
# clf_summary(train_seeds)

training_games = map_seeds_to_states(all_solutions)

for i, env in enumerate(training_games):
    seed, klonstate = env
#     print(seed)
    ep_reward = 0
    done = False
    path = []
    visited = set()
    for t in range(1, 1000):
        action_idx = select_action(klonstate)
        move_code = all_moves[action_idx]
        klonstate, reward = step(klonstate, move_code)
        path.append(move_code)
        if klonstate in visited:
            reward = -1
        else:
            visited.add(klonstate)
        done = reward != 0
        policy.rewards.append(reward)
        ep_reward += reward
        if done:
            break
    print(f"{i:4}  ep reward {ep_reward:.2f}   steps {t:3}   ")#, end=' ')
    if ep_reward > 0:
        print("Solved?!!")
        print(to_pretty_string(klonstate))
#     print('final score', score_state(klonstate))
#     print('path', path)
#     print('final state')
#     print(to_pretty_string(klonstate))
    
    finish_episode()
# Out:
#    0  ep reward -1.00   steps   3
#    1  ep reward -1.00   steps   8
#    2  ep reward -1.00   steps  17
#    3  ep reward -1.00   steps   5
#    4  ep reward -1.00   steps   4
#    5  ep reward -1.00   steps  16
#    6  ep reward -1.00   steps   9
#    7  ep reward -1.00   steps   3
#    8  ep reward -1.00   steps   6
#    9  ep reward -1.00   steps  22
#   10  ep reward -1.00   steps   5
#   11  ep reward -1.00   steps   5
#   12  ep reward -1.00   steps  16
#   13  ep reward -1.00   steps  22
#   14  ep reward -1.00   steps   6
#   15  ep reward -1.00   steps   4
#   16  ep reward -1.00   steps   7
#   17  ep reward -1.00   steps   7
#   18  ep reward -1.00   steps   6
#   19  ep reward -1.00   steps   9
#   20  ep reward -1.00   steps   7
#   21  ep reward -1.00   steps   5
#   22  ep reward -1.00   steps   9
#   23  ep reward -1.00   steps  10
#   24  ep reward -1.00   steps  26
#   25  ep reward -1.00   steps   3
#   26  ep reward -1.00   steps   7
#   27  ep reward -1.00   steps  14
#   28  ep reward -1.00   steps  24
#   29  ep reward -1.00   steps  22
#   30  ep reward -1.00   steps   3
#   31  ep reward -1.00   steps   9
#   32  ep reward -1.00   steps   6
#   33  ep reward -1.00   steps  10
#   34  ep reward -1.00   steps   8
#   35  ep reward -1.00   steps  12
#   36  ep reward -1.00   steps   3
#   37  ep reward -1.00   steps  13
#   38  ep reward -1.00   steps  17
#   39  ep reward -1.00   steps   4
#   40  ep reward -1.00   steps   8
#   41  ep reward -1.00   steps   4
#   42  ep reward -1.00   steps   7
#   43  ep reward -1.00   steps  18
#   44  ep reward -1.00   steps   6
#   45  ep reward -1.00   steps   4
#   46  ep reward -1.00   steps   5
#   47  ep reward -1.00   steps   5
#   48  ep reward -1.00   steps   4
#   49  ep reward -1.00   steps   7
#   50  ep reward -1.00   steps   4
#   51  ep reward -1.00   steps  12
#   52  ep reward -1.00   steps   8
#   53  ep reward -1.00   steps  12
#   54  ep reward -1.00   steps  10
#   55  ep reward -1.00   steps   3
#   56  ep reward -1.00   steps  11
#   57  ep reward -1.00   steps   5
#   58  ep reward -1.00   steps   4
#   59  ep reward -1.00   steps   4
#   60  ep reward -1.00   steps  17
#   61  ep reward -1.00   steps   5
#   62  ep reward -1.00   steps   5
#   63  ep reward -1.00   steps  11
#   64  ep reward -1.00   steps   5
#   65  ep reward -1.00   steps  10
#   66  ep reward -1.00   steps   4
#   67  ep reward -1.00   steps   6
#   68  ep reward -1.00   steps  17
#   69  ep reward -1.00   steps   5
#   70  ep reward -1.00   steps   6
#   71  ep reward -1.00   steps  13
#   72  ep reward -1.00   steps   9
#   73  ep reward -1.00   steps   5
#   74  ep reward -1.00   steps   5
#   75  ep reward -1.00   steps   4
#   76  ep reward -1.00   steps   5
#   77  ep reward -1.00   steps   6
#   78  ep reward -1.00   steps   7
#   79  ep reward -1.00   steps  12
#   80  ep reward -1.00   steps   4
#   81  ep reward -1.00   steps   3
#   82  ep reward -1.00   steps  19
#   83  ep reward -1.00   steps   5
#   84  ep reward -1.00   steps   9
#   85  ep reward -1.00   steps   7
#   86  ep reward -1.00   steps   6
#   87  ep reward -1.00   steps  10
#   88  ep reward -1.00   steps   5
#   89  ep reward -1.00   steps   6
#   90  ep reward -1.00   steps   6
#   91  ep reward -1.00   steps   6
#   92  ep reward -1.00   steps   5
#   93  ep reward -1.00   steps   3
#   94  ep reward -1.00   steps   6
#   95  ep reward -1.00   steps  12
#   96  ep reward -1.00   steps   7
#   97  ep reward -1.00   steps  10
#   98  ep reward -1.00   steps  19
#   99  ep reward -1.00   steps   8
#  100  ep reward -1.00   steps   5
#  101  ep reward -1.00   steps   3
#  102  ep reward -1.00   steps   3
#  103  ep reward -1.00   steps  14
#  104  ep reward -1.00   steps   4
#  105  ep reward -1.00   steps  10
#  106  ep reward -1.00   steps   9
#  107  ep reward -1.00   steps  10
#  108  ep reward -1.00   steps   5
#  109  ep reward -1.00   steps  16
#  110  ep reward -1.00   steps  13
#  111  ep reward -1.00   steps  14
#  112  ep reward -1.00   steps   3
#  113  ep reward -1.00   steps   8
#  114  ep reward -1.00   steps   3
#  115  ep reward -1.00   steps   3
#  116  ep reward -1.00   steps   5
#  117  ep reward -1.00   steps   4
#  118  ep reward -1.00   steps   6
#  119  ep reward -1.00   steps   6
#  120  ep reward -1.00   steps  19
#  121  ep reward -1.00   steps   9
#  122  ep reward -1.00   steps  14
#  123  ep reward -1.00   steps   9
#  124  ep reward -1.00   steps   6
#  125  ep reward -1.00   steps  11
#  126  ep reward -1.00   steps   9
#  127  ep reward -1.00   steps   5
#  128  ep reward -1.00   steps   6
#  129  ep reward -1.00   steps  11
#  130  ep reward -1.00   steps   6
#  131  ep reward -1.00   steps   5
#  132  ep reward -1.00   steps   5
#  133  ep reward -1.00   steps  23
#  134  ep reward -1.00   steps   4
#  135  ep reward -1.00   steps   8
#  136  ep reward -1.00   steps   3
#  137  ep reward -1.00   steps   4
#  138  ep reward -1.00   steps  14
#  139  ep reward -1.00   steps   4
#  140  ep reward -1.00   steps   4
#  141  ep reward -1.00   steps  10
#  142  ep reward -1.00   steps   4
#  143  ep reward -1.00   steps   6
#  144  ep reward -1.00   steps   6
#  145  ep reward -1.00   steps   8
#  146  ep reward -1.00   steps   7
#  147  ep reward -1.00   steps   5
#  148  ep reward -1.00   steps   5
#  149  ep reward -1.00   steps  23
#  150  ep reward -1.00   steps   6
#  151  ep reward -1.00   steps   5
#  152  ep reward -1.00   steps   9
#  153  ep reward -1.00   steps   4
#  154  ep reward -1.00   steps  12
#  155  ep reward -1.00   steps   8
#  156  ep reward -1.00   steps   7
#  157  ep reward -1.00   steps   6
#  158  ep reward -1.00   steps   5
#  159  ep reward -1.00   steps   6
#  160  ep reward -1.00   steps  23
#  161  ep reward -1.00   steps   9
#  162  ep reward -1.00   steps  10
#  163  ep reward -1.00   steps  17
#  164  ep reward -1.00   steps   8
#  165  ep reward -1.00   steps   9
#  166  ep reward -1.00   steps  11
#  167  ep reward -1.00   steps   7
#  168  ep reward -1.00   steps   7
#  169  ep reward -1.00   steps  13
#  170  ep reward -1.00   steps   8
#  171  ep reward -1.00   steps   4
#  172  ep reward -1.00   steps   8
#  173  ep reward -1.00   steps  27
#  174  ep reward -1.00   steps   7
#  175  ep reward -1.00   steps   9
#  176  ep reward -1.00   steps  10
#  177  ep reward -1.00   steps  12
#  178  ep reward -1.00   steps  15
#  179  ep reward -1.00   steps  12
#  180  ep reward -1.00   steps   5
#  181  ep reward -1.00   steps   8
#  182  ep reward -1.00   steps   8
#  183  ep reward -1.00   steps   6
#  184  ep reward -1.00   steps   3
#  185  ep reward -1.00   steps   3
#  186  ep reward -1.00   steps   5
#  187  ep reward -1.00   steps  17
#  188  ep reward -1.00   steps   5
#  189  ep reward -1.00   steps   6
#  190  ep reward -1.00   steps   6
#  191  ep reward -1.00   steps   5
#  192  ep reward -1.00   steps   4
#  193  ep reward -1.00   steps  15
#  194  ep reward -1.00   steps   3
#  195  ep reward -1.00   steps   6
#  196  ep reward -1.00   steps   9
#  197  ep reward -1.00   steps  12
#  198  ep reward -1.00   steps  20
#  199  ep reward -1.00   steps  20
#  200  ep reward -1.00   steps   6
#  201  ep reward -1.00   steps  24
#  202  ep reward -1.00   steps   4
#  203  ep reward -1.00   steps   8
#  204  ep reward -1.00   steps   5
#  205  ep reward -1.00   steps   7
#  206  ep reward -1.00   steps   3
#  207  ep reward -1.00   steps   5
#  208  ep reward -1.00   steps   7
#  209  ep reward -1.00   steps   4
#  210  ep reward -1.00   steps  18
#  211  ep reward -1.00   steps   5
#  212  ep reward -1.00   steps  10
#  213  ep reward -1.00   steps  12
#  214  ep reward -1.00   steps  15
#  215  ep reward -1.00   steps   8
#  216  ep reward -1.00   steps   9
#  217  ep reward -1.00   steps  25
#  218  ep reward -1.00   steps  21
#  219  ep reward -1.00   steps   8
#  220  ep reward -1.00   steps   5
#  221  ep reward -1.00   steps   6
#  222  ep reward -1.00   steps   9
#  223  ep reward -1.00   steps   8
#  224  ep reward -1.00   steps  25
#  225  ep reward -1.00   steps   3
#  226  ep reward -1.00   steps  24
#  227  ep reward -1.00   steps  17
#  228  ep reward -1.00   steps  25
#  229  ep reward -1.00   steps   8
#  230  ep reward -1.00   steps  19
#  231  ep reward -1.00   steps   8
#  232  ep reward -1.00   steps   9
#  233  ep reward -1.00   steps   9
#  234  ep reward -1.00   steps   5
#  235  ep reward -1.00   steps   7
#  236  ep reward -1.00   steps   5
#  237  ep reward -1.00   steps   6
#  238  ep reward -1.00   steps   7
#  239  ep reward -1.00   steps   8
#  240  ep reward -1.00   steps  19
#  241  ep reward -1.00   steps   7
#  242  ep reward -1.00   steps  12
#  243  ep reward -1.00   steps   6
#  244  ep reward -1.00   steps  11
#  245  ep reward -1.00   steps   5
#  246  ep reward -1.00   steps  14
#  247  ep reward -1.00   steps   9
#  248  ep reward -1.00   steps   5
#  249  ep reward -1.00   steps  13
#  250  ep reward -1.00   steps  39
#  251  ep reward -1.00   steps   4
#  252  ep reward -1.00   steps  12
#  253  ep reward -1.00   steps   8
#  254  ep reward -1.00   steps   5
#  255  ep reward -1.00   steps  18
#  256  ep reward -1.00   steps   3
#  257  ep reward -1.00   steps   7
#  258  ep reward -1.00   steps   8
#  259  ep reward -1.00   steps  10
#  260  ep reward -1.00   steps   7
#  261  ep reward -1.00   steps  16
#  262  ep reward -1.00   steps   5
#  263  ep reward -1.00   steps  19
#  264  ep reward -1.00   steps   7
#  265  ep reward -1.00   steps  10
#  266  ep reward -1.00   steps   8
#  267  ep reward -1.00   steps  12
#  268  ep reward -1.00   steps   3
#  269  ep reward -1.00   steps  11
#  270  ep reward -1.00   steps   5
#  271  ep reward -1.00   steps   5
#  272  ep reward -1.00   steps  25
#  273  ep reward -1.00   steps   4
#  274  ep reward -1.00   steps  20
#  275  ep reward -1.00   steps  12
#  276  ep reward -1.00   steps  14
#  277  ep reward -1.00   steps   7
#  278  ep reward -1.00   steps  12
#  279  ep reward -1.00   steps   4
#  280  ep reward -1.00   steps   6
#  281  ep reward -1.00   steps  22
#  282  ep reward -1.00   steps   5
#  283  ep reward -1.00   steps  13
#  284  ep reward -1.00   steps   5
#  285  ep reward -1.00   steps  15
#  286  ep reward -1.00   steps   4
#  287  ep reward -1.00   steps  18
#  288  ep reward -1.00   steps   6
#  289  ep reward -1.00   steps   5
#  290  ep reward -1.00   steps   5
#  291  ep reward -1.00   steps   6
#  292  ep reward -1.00   steps  10
#  293  ep reward -1.00   steps  13
#  294  ep reward -1.00   steps   6
#  295  ep reward -1.00   steps   6
#  296  ep reward -1.00   steps   4
#  297  ep reward -1.00   steps   3
#  298  ep reward -1.00   steps   7
#  299  ep reward -1.00   steps   8
#  300  ep reward -1.00   steps   3
#  301  ep reward -1.00   steps   7
#  302  ep reward -1.00   steps  29
#  303  ep reward -1.00   steps   7
#  304  ep reward -1.00   steps  10
#  305  ep reward -1.00   steps   8
#  306  ep reward -1.00   steps   3
#  307  ep reward -1.00   steps   5
#  308  ep reward -1.00   steps   8
#  309  ep reward -1.00   steps   9
#  310  ep reward -1.00   steps   9
#  311  ep reward -1.00   steps   4
#  312  ep reward -1.00   steps  12
#  313  ep reward -1.00   steps   8
#  314  ep reward -1.00   steps   8
#  315  ep reward -1.00   steps   5
#  316  ep reward -1.00   steps   3
#  317  ep reward -1.00   steps  12
#  318  ep reward -1.00   steps   8
#  319  ep reward -1.00   steps   6
#  320  ep reward -1.00   steps   8
#  321  ep reward -1.00   steps   3
#  322  ep reward -1.00   steps  10
#  323  ep reward -1.00   steps   5
#  324  ep reward -1.00   steps   6
#  325  ep reward -1.00   steps  12
#  326  ep reward -1.00   steps   6
#  327  ep reward -1.00   steps  18
#  328  ep reward -1.00   steps   7
#  329  ep reward -1.00   steps  22
#  330  ep reward -1.00   steps   3
#  331  ep reward -1.00   steps   9
#  332  ep reward -1.00   steps  10
#  333  ep reward -1.00   steps   7
#  334  ep reward -1.00   steps  23
#  335  ep reward -1.00   steps  16
#  336  ep reward -1.00   steps  21
#  337  ep reward -1.00   steps  11
#  338  ep reward -1.00   steps   8
#  339  ep reward -1.00   steps   7
#  340  ep reward -1.00   steps   8
#  341  ep reward -1.00   steps  15
#  342  ep reward -1.00   steps   7
#  343  ep reward -1.00   steps  26
#  344  ep reward -1.00   steps   9
#  345  ep reward -1.00   steps  14
#  346  ep reward -1.00   steps   9
#  347  ep reward -1.00   steps  10
#  348  ep reward -1.00   steps  19
#  349  ep reward -1.00   steps   8
#  350  ep reward -1.00   steps   4
#  351  ep reward -1.00   steps  10
#  352  ep reward -1.00   steps   4
#  353  ep reward -1.00   steps  19
#  354  ep reward -1.00   steps   9
#  355  ep reward -1.00   steps   6
#  356  ep reward -1.00   steps   8
#  357  ep reward -1.00   steps   6
#  358  ep reward -1.00   steps  12
#  359  ep reward -1.00   steps  14
#  360  ep reward -1.00   steps  13
#  361  ep reward -1.00   steps   3
#  362  ep reward -1.00   steps  10
#  363  ep reward -1.00   steps   8
#  364  ep reward -1.00   steps   6
#  365  ep reward -1.00   steps  10
#  366  ep reward -1.00   steps   4
#  367  ep reward -1.00   steps   4
#  368  ep reward -1.00   steps   7
#  369  ep reward -1.00   steps   3
#  370  ep reward -1.00   steps  14
#  371  ep reward -1.00   steps   4
#  372  ep reward -1.00   steps  28
#  373  ep reward -1.00   steps   8
#  374  ep reward -1.00   steps  16
#  375  ep reward -1.00   steps  11
#  376  ep reward -1.00   steps  20
#  377  ep reward -1.00   steps  10
#  378  ep reward -1.00   steps   7
#  379  ep reward -1.00   steps   4
#  380  ep reward -1.00   steps   4
#  381  ep reward -1.00   steps   8
#  382  ep reward -1.00   steps  12
#  383  ep reward -1.00   steps  20
#  384  ep reward -1.00   steps   7
#  385  ep reward -1.00   steps   8
#  386  ep reward -1.00   steps  10
#  387  ep reward -1.00   steps   3
#  388  ep reward -1.00   steps   7
#  389  ep reward -1.00   steps  16
#  390  ep reward -1.00   steps  13
#  391  ep reward -1.00   steps   6
#  392  ep reward -1.00   steps  15
#  393  ep reward -1.00   steps   7
#  394  ep reward -1.00   steps  20
#  395  ep reward -1.00   steps   6
#  396  ep reward -1.00   steps  10
#  397  ep reward -1.00   steps   6
#  398  ep reward -1.00   steps   8
#  399  ep reward -1.00   steps  10
#  400  ep reward -1.00   steps   9
#  401  ep reward -1.00   steps   8
#  402  ep reward -1.00   steps   5
#  403  ep reward -1.00   steps   9
#  404  ep reward -1.00   steps  24
#  405  ep reward -1.00   steps   4
#  406  ep reward -1.00   steps  26
#  407  ep reward -1.00   steps   8
#  408  ep reward -1.00   steps   5
#  409  ep reward -1.00   steps  13
#  410  ep reward -1.00   steps   8
#  411  ep reward -1.00   steps  11
#  412  ep reward -1.00   steps   7
#  413  ep reward -1.00   steps   3
#  414  ep reward -1.00   steps   5
#  415  ep reward -1.00   steps   3
#  416  ep reward -1.00   steps   7
#  417  ep reward -1.00   steps   7
#  418  ep reward -1.00   steps  25
#  419  ep reward -1.00   steps   8
#  420  ep reward -1.00   steps   4
#  421  ep reward -1.00   steps   8
#  422  ep reward -1.00   steps   6
#  423  ep reward -1.00   steps   6
#  424  ep reward -1.00   steps   6
#  425  ep reward -1.00   steps   4
#  426  ep reward -1.00   steps   6
#  427  ep reward -1.00   steps  11
#  428  ep reward -1.00   steps  13
#  429  ep reward -1.00   steps   8
#  430  ep reward -1.00   steps   5
#  431  ep reward -1.00   steps  19
#  432  ep reward -1.00   steps  21
#  433  ep reward -1.00   steps   9
#  434  ep reward -1.00   steps   3
#  435  ep reward -1.00   steps   4
#  436  ep reward -1.00   steps  12
#  437  ep reward -1.00   steps  11
#  438  ep reward -1.00   steps   9
#  439  ep reward -1.00   steps  12
#  440  ep reward -1.00   steps  15
#  441  ep reward -1.00   steps   3
#  442  ep reward -1.00   steps   7
#  443  ep reward -1.00   steps  10
#  444  ep reward -1.00   steps  41
#  445  ep reward -1.00   steps  12
#  446  ep reward -1.00   steps   6
#  447  ep reward -1.00   steps  11
#  448  ep reward -1.00   steps   9
#  449  ep reward -1.00   steps  15
#  450  ep reward -1.00   steps  10
#  451  ep reward -1.00   steps   4
#  452  ep reward -1.00   steps   8
#  453  ep reward -1.00   steps   7
#  454  ep reward -1.00   steps  12
#  455  ep reward -1.00   steps  10
#  456  ep reward -1.00   steps  13
#  457  ep reward -1.00   steps  18
#  458  ep reward -1.00   steps  17
#  459  ep reward -1.00   steps   6
#  460  ep reward -1.00   steps  16
#  461  ep reward -1.00   steps  11
#  462  ep reward -1.00   steps  17
#  463  ep reward -1.00   steps   7
#  464  ep reward -1.00   steps   6
#  465  ep reward -1.00   steps   9
#  466  ep reward -1.00   steps  29
#  467  ep reward -1.00   steps  15
#  468  ep reward -1.00   steps  13
#  469  ep reward -1.00   steps  17
#  470  ep reward -1.00   steps  24
#  471  ep reward -1.00   steps  20
#  472  ep reward -1.00   steps   7
#  473  ep reward -1.00   steps   9
#  474  ep reward -1.00   steps   5
#  475  ep reward -1.00   steps  10
#  476  ep reward -1.00   steps   5
#  477  ep reward -1.00   steps   3
#  478  ep reward -1.00   steps  13
#  479  ep reward -1.00   steps   6
#  480  ep reward -1.00   steps  15
#  481  ep reward -1.00   steps   9
#  482  ep reward -1.00   steps  18
#  483  ep reward -1.00   steps  10
#  484  ep reward -1.00   steps  27
#  485  ep reward -1.00   steps  16
#  486  ep reward -1.00   steps  12
#  487  ep reward -1.00   steps   6
#  488  ep reward -1.00   steps  24
#  489  ep reward -1.00   steps   6
#  490  ep reward -1.00   steps  19
#  491  ep reward -1.00   steps  15
#  492  ep reward -1.00   steps   3
#  493  ep reward -1.00   steps  14
#  494  ep reward -1.00   steps  25
#  495  ep reward -1.00   steps  11
#  496  ep reward -1.00   steps   9
#  497  ep reward -1.00   steps   9
#  498  ep reward -1.00   steps  17
#  499  ep reward -1.00   steps   7
#  500  ep reward -1.00   steps   3
#  501  ep reward -1.00   steps  10
#  502  ep reward -1.00   steps  20
#  503  ep reward -1.00   steps   6
#  504  ep reward -1.00   steps   6
#  505  ep reward -1.00   steps  28
#  506  ep reward -1.00   steps  15
#  507  ep reward -1.00   steps  13
#  508  ep reward -1.00   steps   6
#  509  ep reward -1.00   steps   7
#  510  ep reward -1.00   steps  11
#  511  ep reward -1.00   steps  24
#  512  ep reward -1.00   steps  33
#  513  ep reward -1.00   steps  33
#  514  ep reward -1.00   steps  15
#  515  ep reward -1.00   steps  16
#  516  ep reward -1.00   steps   5
#  517  ep reward -1.00   steps   9
#  518  ep reward -1.00   steps  51
#  519  ep reward -1.00   steps   9
#  520  ep reward -1.00   steps  16
#  521  ep reward -1.00   steps  15
#  522  ep reward -1.00   steps  10
#  523  ep reward -1.00   steps   5
#  524  ep reward -1.00   steps  15
#  525  ep reward -1.00   steps   7
#  526  ep reward -1.00   steps   4
#  527  ep reward -1.00   steps  10
#  528  ep reward -1.00   steps   8
#  529  ep reward -1.00   steps  12
#  530  ep reward -1.00   steps  10
#  531  ep reward -1.00   steps  16
#  532  ep reward -1.00   steps   7
#  533  ep reward -1.00   steps   6
#  534  ep reward -1.00   steps  18
#  535  ep reward -1.00   steps  31
#  536  ep reward -1.00   steps   9
#  537  ep reward -1.00   steps  17
#  538  ep reward -1.00   steps  13
#  539  ep reward -1.00   steps  42
#  540  ep reward -1.00   steps   4
#  541  ep reward -1.00   steps  23
#  542  ep reward -1.00   steps   5
#  543  ep reward -1.00   steps  14
#  544  ep reward -1.00   steps  15
#  545  ep reward -1.00   steps  14
#  546  ep reward -1.00   steps  10
#  547  ep reward -1.00   steps  14
#  548  ep reward -1.00   steps  11
#  549  ep reward -1.00   steps   5
#  550  ep reward -1.00   steps   8
#  551  ep reward -1.00   steps  13
#  552  ep reward -1.00   steps  12
#  553  ep reward -1.00   steps  10
#  554  ep reward -1.00   steps   7
#  555  ep reward -1.00   steps  12
#  556  ep reward -1.00   steps  11
#  557  ep reward -1.00   steps   7
#  558  ep reward -1.00   steps  10
#  559  ep reward -1.00   steps  42
#  560  ep reward -1.00   steps   8
#  561  ep reward -1.00   steps  18
#  562  ep reward -1.00   steps   8
#  563  ep reward -1.00   steps  12
#  564  ep reward -1.00   steps   8
#  565  ep reward -1.00   steps   5
#  566  ep reward -1.00   steps   4
#  567  ep reward -1.00   steps  14
#  568  ep reward -1.00   steps  11
#  569  ep reward -1.00   steps  14
#  570  ep reward -1.00   steps  33
#  571  ep reward -1.00   steps   8
#  572  ep reward -1.00   steps   5
#  573  ep reward -1.00   steps  15
#  574  ep reward -1.00   steps  16
#  575  ep reward -1.00   steps  29
#  576  ep reward -1.00   steps  11
#  577  ep reward -1.00   steps  13
#  578  ep reward -1.00   steps  19
#  579  ep reward -1.00   steps   5
#  580  ep reward -1.00   steps   6
#  581  ep reward -1.00   steps  26
#  582  ep reward -1.00   steps   9
#  583  ep reward -1.00   steps   7
#  584  ep reward -1.00   steps   5
#  585  ep reward -1.00   steps  27
#  586  ep reward -1.00   steps  33
#  587  ep reward -1.00   steps  37
#  588  ep reward -1.00   steps  11
#  589  ep reward -1.00   steps  10
#  590  ep reward -1.00   steps  10
#  591  ep reward -1.00   steps   5
#  592  ep reward -1.00   steps   7
#  593  ep reward -1.00   steps  11
#  594  ep reward -1.00   steps  58
#  595  ep reward -1.00   steps  20
#  596  ep reward -1.00   steps  10
#  597  ep reward -1.00   steps  35
#  598  ep reward -1.00   steps   6
#  599  ep reward -1.00   steps  13
#  600  ep reward -1.00   steps   9
#  601  ep reward -1.00   steps  22
#  602  ep reward -1.00   steps  21
#  603  ep reward -1.00   steps   9
#  604  ep reward -1.00   steps   9
#  605  ep reward -1.00   steps  17
#  606  ep reward -1.00   steps  40
#  607  ep reward -1.00   steps   9
#  608  ep reward -1.00   steps   9
#  609  ep reward -1.00   steps   9
#  610  ep reward -1.00   steps   9
#  611  ep reward -1.00   steps   7
#  612  ep reward -1.00   steps   9
#  613  ep reward -1.00   steps   9
#  614  ep reward -1.00   steps  17
#  615  ep reward -1.00   steps   9
#  616  ep reward -1.00   steps   9
#  617  ep reward -1.00   steps   9
#  618  ep reward -1.00   steps  29
#  619  ep reward -1.00   steps   9
#  620  ep reward -1.00   steps   9
#  621  ep reward -1.00   steps   9
#  622  ep reward -1.00   steps  23
#  623  ep reward -1.00   steps  16
#  624  ep reward -1.00   steps  24
#  625  ep reward -1.00   steps  17
#  626  ep reward -1.00   steps  19
#  627  ep reward -1.00   steps  60
#  628  ep reward -1.00   steps  28
#  629  ep reward -1.00   steps  31
#  630  ep reward -1.00   steps  38
#  631  ep reward -1.00   steps   9
#  632  ep reward -1.00   steps  40
#  633  ep reward -1.00   steps   9
#  634  ep reward -1.00   steps  16
#  635  ep reward -1.00   steps  10
#  636  ep reward -1.00   steps  15
#  637  ep reward -1.00   steps  14
#  638  ep reward -1.00   steps  31
#  639  ep reward -1.00   steps   9
#  640  ep reward -1.00   steps  18
#  641  ep reward -1.00   steps  35
#  642  ep reward -1.00   steps  23
#  643  ep reward -1.00   steps  18
#  644  ep reward -1.00   steps  14
#  645  ep reward -1.00   steps  29
#  646  ep reward -1.00   steps  39
#  647  ep reward -1.00   steps  18
#  648  ep reward -1.00   steps  37
#  649  ep reward -1.00   steps  42
#  650  ep reward -1.00   steps  15
#  651  ep reward -1.00   steps  16
#  652  ep reward -1.00   steps  18
#  653  ep reward -1.00   steps  14
#  654  ep reward -1.00   steps  19
#  655  ep reward -1.00   steps  27
#  656  ep reward -1.00   steps  13
#  657  ep reward -1.00   steps  52
#  658  ep reward -1.00   steps  13
#  659  ep reward -1.00   steps  27
#  660  ep reward -1.00   steps  40
#  661  ep reward -1.00   steps  16
#  662  ep reward -1.00   steps   8
#  663  ep reward -1.00   steps  40
#  664  ep reward -1.00   steps  17
#  665  ep reward -1.00   steps  26
#  666  ep reward -1.00   steps  19
#  667  ep reward -1.00   steps  16
#  668  ep reward -1.00   steps  14
#  669  ep reward -1.00   steps  41
#  670  ep reward -1.00   steps  26
#  671  ep reward -1.00   steps  40
#  672  ep reward -1.00   steps   6
#  673  ep reward -1.00   steps  45
#  674  ep reward -1.00   steps  22

# %%
# klonstate = random_solved_endgame(20)
# print(to_pretty_string(klonstate))
# print()

# done = False
# visited = set()
# for i in range(500):
#     visited.add(klonstate)
#     action = select_action(klonstate)
# #     print(f'iteration {i}  action {all_moves[action]}')
#     klonstate, reward = step(klonstate, action)
#     done = reward > 0
#     if done:
#         break

# print()
# if done:
#     print("Solved!")
# else:
#     print(f'Not solved after {i+1} iterations')
    
# print(to_pretty_string(klonstate))
